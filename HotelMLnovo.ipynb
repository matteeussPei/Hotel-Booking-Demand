# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime 

from pandas.plotting import scatter_matrix
import warnings
warnings.filterwarnings("ignore")

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('hotel_bookings.csv')
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# 1                        0                     0       2       0.0       0
# 2                        0                     1       1       0.0       0
# 3                        0                     1       1       0.0       0
# 4                        0                     2       2       0.0       0
#
#   meal country market_segment distribution_channel  is_repeated_guest  \
# 0   BB     PRT         Direct               Direct                  0
# 1   BB     PRT         Direct               Direct                  0
# 2   BB     GBR         Direct               Direct                  0
# 3   BB     GBR      Corporate            Corporate                  0
# 4   BB     GBR      Online TA                TA/TO                  0
#
#    previous_cancellations  previous_bookings_not_canceled reserved_room_type  \
# 0                       0                               0                  C
# 1                       0                               0                  C
# 2                       0                               0                  A
# 3                       0                               0                  A
# 4                       0                               0                  A
#
#   assigned_room_type  booking_changes deposit_type  agent  company  \
# 0                  C                3   No Deposit    NaN      NaN
# 1                  C                4   No Deposit    NaN      NaN
# 2                  C                0   No Deposit    NaN      NaN
# 3                  A                0   No Deposit  304.0      NaN
# 4                  A                0   No Deposit  240.0      NaN
#
#    days_in_waiting_list customer_type   adr  required_car_parking_spaces  \
# 0                     0     Transient   0.0                            0
# 1                     0     Transient   0.0                            0
# 2                     0     Transient  75.0                            0
# 3                     0     Transient  75.0                            0
# 4                     0     Transient  98.0                            0
#
#    total_of_special_requests reservation_status reservation_status_date
# 0                          0          Check-Out              2015-07-01
# 1                          0          Check-Out              2015-07-01
# 2                          0          Check-Out              2015-07-02
# 3                          0          Check-Out              2015-07-02
# 4                          1          Check-Out              2015-07-03

# %%
print('Total de variáveis:', df.shape[1])
print('Total de entradas:', df.shape[0])
# Out:
# Total de variáveis: 32
# Total de entradas: 119390

# %%
df['is_canceled'].mean()
# Out:
# 0.37041628277075134

# %%
pd.DataFrame({'tipo de dados':df.dtypes,
                'dados_ausentes(%)': (df.isnull().sum()/df.shape[0])*100,
                    'valores unicos': df.nunique()}).sort_values(by='dados_ausentes(%)', ascending=False)
# Out:
#                                tipo de dados  dados_ausentes(%)  \
# company                              float64          94.306893
# agent                                float64          13.686238
# country                               object           0.408744
# children                             float64           0.003350
# reserved_room_type                    object           0.000000
# assigned_room_type                    object           0.000000
# booking_changes                        int64           0.000000
# deposit_type                          object           0.000000
# hotel                                 object           0.000000
# previous_cancellations                 int64           0.000000
# days_in_waiting_list                   int64           0.000000
# customer_type                         object           0.000000
# adr                                  float64           0.000000
# required_car_parking_spaces            int64           0.000000
# total_of_special_requests              int64           0.000000
# reservation_status                    object           0.000000
# previous_bookings_not_canceled         int64           0.000000
# is_repeated_guest                      int64           0.000000
# is_canceled                            int64           0.000000
# distribution_channel                  object           0.000000
# market_segment                        object           0.000000
# meal                                  object           0.000000
# babies                                 int64           0.000000
# adults                                 int64           0.000000
# stays_in_week_nights                   int64           0.000000
# stays_in_weekend_nights                int64           0.000000
# arrival_date_day_of_month              int64           0.000000
# arrival_date_week_number               int64           0.000000
# arrival_date_month                    object           0.000000
# arrival_date_year                      int64           0.000000
# lead_time                              int64           0.000000
# reservation_status_date               object           0.000000
#
#                                 valores unicos
# company                                    352
# agent                                      333
# country                                    177
# children                                     5
# reserved_room_type                          10
# assigned_room_type                          12
# booking_changes                             21
# deposit_type                                 3
# hotel                                        2
# previous_cancellations                      15
# days_in_waiting_list                       128
# customer_type                                4
# adr                                       8879
# required_car_parking_spaces                  5
# total_of_special_requests                    6
# reservation_status                           3
# previous_bookings_not_canceled              73
# is_repeated_guest                            2
# is_canceled                                  2
# distribution_channel                         5
# market_segment                               8
# meal                                         5
# babies                                       5
# adults                                      14
# stays_in_week_nights                        35
# stays_in_weekend_nights                     17
# arrival_date_day_of_month                   31
# arrival_date_week_number                    53
# arrival_date_month                          12
# arrival_date_year                            3
# lead_time                                  479
# reservation_status_date                    926

# %%
df.drop(columns = ['agent', 'company'], inplace=True)

# %%
pd.DataFrame({'tipo de dados':df.dtypes,
                'dados_ausentes(%)': (df.isnull().sum()/df.shape[0])*100,
                    'valores unicos': df.nunique()}).sort_values(by='dados_ausentes(%)', ascending=False)
# Out:
#                                tipo de dados  dados_ausentes(%)  \
# country                               object           0.408744
# children                             float64           0.003350
# hotel                                 object           0.000000
# is_repeated_guest                      int64           0.000000
# reservation_status                    object           0.000000
# total_of_special_requests              int64           0.000000
# required_car_parking_spaces            int64           0.000000
# adr                                  float64           0.000000
# customer_type                         object           0.000000
# days_in_waiting_list                   int64           0.000000
# deposit_type                          object           0.000000
# booking_changes                        int64           0.000000
# assigned_room_type                    object           0.000000
# reserved_room_type                    object           0.000000
# previous_bookings_not_canceled         int64           0.000000
# previous_cancellations                 int64           0.000000
# distribution_channel                  object           0.000000
# is_canceled                            int64           0.000000
# market_segment                        object           0.000000
# meal                                  object           0.000000
# babies                                 int64           0.000000
# adults                                 int64           0.000000
# stays_in_week_nights                   int64           0.000000
# stays_in_weekend_nights                int64           0.000000
# arrival_date_day_of_month              int64           0.000000
# arrival_date_week_number               int64           0.000000
# arrival_date_month                    object           0.000000
# arrival_date_year                      int64           0.000000
# lead_time                              int64           0.000000
# reservation_status_date               object           0.000000
#
#                                 valores unicos
# country                                    177
# children                                     5
# hotel                                        2
# is_repeated_guest                            2
# reservation_status                           3
# total_of_special_requests                    6
# required_car_parking_spaces                  5
# adr                                       8879
# customer_type                                4
# days_in_waiting_list                       128
# deposit_type                                 3
# booking_changes                             21
# assigned_room_type                          12
# reserved_room_type                          10
# previous_bookings_not_canceled              73
# previous_cancellations                      15
# distribution_channel                         5
# is_canceled                                  2
# market_segment                               8
# meal                                         5
# babies                                       5
# adults                                      14
# stays_in_week_nights                        35
# stays_in_weekend_nights                     17
# arrival_date_day_of_month                   31
# arrival_date_week_number                    53
# arrival_date_month                          12
# arrival_date_year                            3
# lead_time                                  479
# reservation_status_date                    926

# %%
df.drop(columns=['country', 'arrival_date_year', 'reservation_status', 'arrival_date_month'], inplace = True)

# %%
df = df.dropna(subset='children').reset_index(drop=True)

# %%
filtro = (df['babies'] == 0) & (df['children'] == 0) & (df['adults'] == 0)
df = df[~filtro]

# %%
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_week_number  \
# 0  Resort Hotel            0        342                        27
# 1  Resort Hotel            0        737                        27
# 2  Resort Hotel            0          7                        27
# 3  Resort Hotel            0         13                        27
# 4  Resort Hotel            0         14                        27
#
#    arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 0                          1                        0                     0
# 1                          1                        0                     0
# 2                          1                        0                     1
# 3                          1                        0                     1
# 4                          1                        0                     2
#
#    adults  children  babies meal market_segment distribution_channel  \
# 0       2       0.0       0   BB         Direct               Direct
# 1       2       0.0       0   BB         Direct               Direct
# 2       1       0.0       0   BB         Direct               Direct
# 3       1       0.0       0   BB      Corporate            Corporate
# 4       2       0.0       0   BB      Online TA                TA/TO
#
#    is_repeated_guest  previous_cancellations  previous_bookings_not_canceled  \
# 0                  0                       0                               0
# 1                  0                       0                               0
# 2                  0                       0                               0
# 3                  0                       0                               0
# 4                  0                       0                               0
#
#   reserved_room_type assigned_room_type  booking_changes deposit_type  \
# 0                  C                  C                3   No Deposit
# 1                  C                  C                4   No Deposit
# 2                  A                  C                0   No Deposit
# 3                  A                  A                0   No Deposit
# 4                  A                  A                0   No Deposit
#
#    days_in_waiting_list customer_type   adr  required_car_parking_spaces  \
# 0                     0     Transient   0.0                            0
# 1                     0     Transient   0.0                            0
# 2                     0     Transient  75.0                            0
# 3                     0     Transient  75.0                            0
# 4                     0     Transient  98.0                            0
#
#    total_of_special_requests reservation_status_date
# 0                          0              2015-07-01
# 1                          0              2015-07-01
# 2                          0              2015-07-02
# 3                          0              2015-07-02
# 4                          1              2015-07-03

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85427 entries, 0 to 119385
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           85427 non-null  object
#  1   is_canceled                     85427 non-null  int64
#  2   lead_time                       85427 non-null  int64
#  3   arrival_date_week_number        85427 non-null  int64
#  4   arrival_date_day_of_month       85427 non-null  int64
#  5   stays_in_weekend_nights         85427 non-null  int64
#  6   stays_in_week_nights            85427 non-null  int64
#  7   adults                          85427 non-null  int64
#  8   children                        85427 non-null  float64
#  9   babies                          85427 non-null  int64
#  10  meal                            85427 non-null  object
#  11  market_segment                  85427 non-null  object
#  12  distribution_channel            85427 non-null  object
#  13  is_repeated_guest               85427 non-null  int64
#  14  previous_cancellations          85427 non-null  int64
#  15  previous_bookings_not_canceled  85427 non-null  int64
#  16  reserved_room_type              85427 non-null  object
#  17  assigned_room_type              85427 non-null  object
#  18  booking_changes                 85427 non-null  int64
#  19  deposit_type                    85427 non-null  object
#  20  days_in_waiting_list            85427 non-null  int64
#  21  customer_type                   85427 non-null  object
#  22  adr                             85427 non-null  float64
#  23  required_car_parking_spaces     85427 non-null  int64
#  24  total_of_special_requests       85427 non-null  int64
#  25  reservation_status_date         85427 non-null  object
# dtypes: float64(2), int64(15), object(9)
# memory usage: 17.6+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85427 entries, 0 to 119385
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           85427 non-null  object
#  1   is_canceled                     85427 non-null  int64
#  2   lead_time                       85427 non-null  int64
#  3   arrival_date_week_number        85427 non-null  int64
#  4   arrival_date_day_of_month       85427 non-null  int64
#  5   stays_in_weekend_nights         85427 non-null  int64
#  6   stays_in_week_nights            85427 non-null  int64
#  7   adults                          85427 non-null  int64
#  8   children                        85427 non-null  float64
#  9   babies                          85427 non-null  int64
#  10  meal                            85427 non-null  object
#  11  market_segment                  85427 non-null  object
#  12  distribution_channel            85427 non-null  object
#  13  is_repeated_guest               85427 non-null  int64
#  14  previous_cancellations          85427 non-null  int64
#  15  previous_bookings_not_canceled  85427 non-null  int64
#  16  reserved_room_type              85427 non-null  object
#  17  assigned_room_type              85427 non-null  object
#  18  booking_changes                 85427 non-null  int64
#  19  deposit_type                    85427 non-null  object
#  20  days_in_waiting_list            85427 non-null  int64
#  21  customer_type                   85427 non-null  object
#  22  adr                             85427 non-null  float64
#  23  required_car_parking_spaces     85427 non-null  int64
#  24  total_of_special_requests       85427 non-null  int64
#  25  reservation_status_date         85427 non-null  object
# dtypes: float64(2), int64(15), object(9)
# memory usage: 17.6+ MB

# %%
df['children'] = df['children'].astype('int64', errors='raise')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85427 entries, 0 to 119385
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           85427 non-null  object
#  1   is_canceled                     85427 non-null  int64
#  2   lead_time                       85427 non-null  int64
#  3   arrival_date_week_number        85427 non-null  int64
#  4   arrival_date_day_of_month       85427 non-null  int64
#  5   stays_in_weekend_nights         85427 non-null  int64
#  6   stays_in_week_nights            85427 non-null  int64
#  7   adults                          85427 non-null  int64
#  8   children                        85427 non-null  int64
#  9   babies                          85427 non-null  int64
#  10  meal                            85427 non-null  object
#  11  market_segment                  85427 non-null  object
#  12  distribution_channel            85427 non-null  object
#  13  is_repeated_guest               85427 non-null  int64
#  14  previous_cancellations          85427 non-null  int64
#  15  previous_bookings_not_canceled  85427 non-null  int64
#  16  reserved_room_type              85427 non-null  object
#  17  assigned_room_type              85427 non-null  object
#  18  booking_changes                 85427 non-null  int64
#  19  deposit_type                    85427 non-null  object
#  20  days_in_waiting_list            85427 non-null  int64
#  21  customer_type                   85427 non-null  object
#  22  adr                             85427 non-null  float64
#  23  required_car_parking_spaces     85427 non-null  int64
#  24  total_of_special_requests       85427 non-null  int64
#  25  reservation_status_date         85427 non-null  object
# dtypes: float64(1), int64(16), object(9)
# memory usage: 17.6+ MB

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_week_number  \
# 0  Resort Hotel            0        342                        27
# 1  Resort Hotel            0        737                        27
# 2  Resort Hotel            0          7                        27
# 3  Resort Hotel            0         13                        27
# 4  Resort Hotel            0         14                        27
#
#    arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 0                          1                        0                     0
# 1                          1                        0                     0
# 2                          1                        0                     1
# 3                          1                        0                     1
# 4                          1                        0                     2
#
#    adults  children  babies meal market_segment distribution_channel  \
# 0       2         0       0   BB         Direct               Direct
# 1       2         0       0   BB         Direct               Direct
# 2       1         0       0   BB         Direct               Direct
# 3       1         0       0   BB      Corporate            Corporate
# 4       2         0       0   BB      Online TA                TA/TO
#
#    is_repeated_guest  previous_cancellations  previous_bookings_not_canceled  \
# 0                  0                       0                               0
# 1                  0                       0                               0
# 2                  0                       0                               0
# 3                  0                       0                               0
# 4                  0                       0                               0
#
#   reserved_room_type assigned_room_type  booking_changes deposit_type  \
# 0                  C                  C                3   No Deposit
# 1                  C                  C                4   No Deposit
# 2                  A                  C                0   No Deposit
# 3                  A                  A                0   No Deposit
# 4                  A                  A                0   No Deposit
#
#    days_in_waiting_list customer_type   adr  required_car_parking_spaces  \
# 0                     0     Transient   0.0                            0
# 1                     0     Transient   0.0                            0
# 2                     0     Transient  75.0                            0
# 3                     0     Transient  75.0                            0
# 4                     0     Transient  98.0                            0
#
#    total_of_special_requests reservation_status_date
# 0                          0              2015-07-01
# 1                          0              2015-07-01
# 2                          0              2015-07-02
# 3                          0              2015-07-02
# 4                          1              2015-07-03

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

df['year'] = df['reservation_status_date'].dt.year
df['month'] = df['reservation_status_date'].dt.month
df['day'] = df['reservation_status_date'].dt.day
df.drop(columns=['reservation_status_date'], inplace=True)

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_week_number  \
# 0  Resort Hotel            0        342                        27
# 1  Resort Hotel            0        737                        27
# 2  Resort Hotel            0          7                        27
# 3  Resort Hotel            0         13                        27
# 4  Resort Hotel            0         14                        27
#
#    arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 0                          1                        0                     0
# 1                          1                        0                     0
# 2                          1                        0                     1
# 3                          1                        0                     1
# 4                          1                        0                     2
#
#    adults  children  babies meal market_segment distribution_channel  \
# 0       2         0       0   BB         Direct               Direct
# 1       2         0       0   BB         Direct               Direct
# 2       1         0       0   BB         Direct               Direct
# 3       1         0       0   BB      Corporate            Corporate
# 4       2         0       0   BB      Online TA                TA/TO
#
#    is_repeated_guest  previous_cancellations  previous_bookings_not_canceled  \
# 0                  0                       0                               0
# 1                  0                       0                               0
# 2                  0                       0                               0
# 3                  0                       0                               0
# 4                  0                       0                               0
#
#   reserved_room_type assigned_room_type  booking_changes deposit_type  \
# 0                  C                  C                3   No Deposit
# 1                  C                  C                4   No Deposit
# 2                  A                  C                0   No Deposit
# 3                  A                  A                0   No Deposit
# 4                  A                  A                0   No Deposit
#
#    days_in_waiting_list customer_type   adr  required_car_parking_spaces  \
# 0                     0     Transient   0.0                            0
# 1                     0     Transient   0.0                            0
# 2                     0     Transient  75.0                            0
# 3                     0     Transient  75.0                            0
# 4                     0     Transient  98.0                            0
#
#    total_of_special_requests  year  month  day
# 0                          0  2015      7    1
# 1                          0  2015      7    1
# 2                          0  2015      7    2
# 3                          0  2015      7    2
# 4                          1  2015      7    3

# %%
from sklearn import preprocessing

# %%
cat_cols = [col for col in df.columns if df[col].dtype == 'O']

# %%
cat_cols.append('year')

# %%
cat_cols
# Out:
# ['hotel',
#  'meal',
#  'market_segment',
#  'distribution_channel',
#  'reserved_room_type',
#  'assigned_room_type',
#  'deposit_type',
#  'customer_type',
#  'year']

# %%
le = preprocessing.LabelEncoder()

# %%
df[cat_cols] = df[cat_cols].apply(le.fit_transform)

# %%
df.head()
# Out:
#    hotel  is_canceled  lead_time  arrival_date_week_number  \
# 0      1            0        342                        27
# 1      1            0        737                        27
# 2      1            0          7                        27
# 3      1            0         13                        27
# 4      1            0         14                        27
#
#    arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 0                          1                        0                     0
# 1                          1                        0                     0
# 2                          1                        0                     1
# 3                          1                        0                     1
# 4                          1                        0                     2
#
#    adults  children  babies  meal  market_segment  distribution_channel  \
# 0       2         0       0     0               3                     1
# 1       2         0       0     0               3                     1
# 2       1         0       0     0               3                     1
# 3       1         0       0     0               2                     0
# 4       2         0       0     0               6                     3
#
#    is_repeated_guest  previous_cancellations  previous_bookings_not_canceled  \
# 0                  0                       0                               0
# 1                  0                       0                               0
# 2                  0                       0                               0
# 3                  0                       0                               0
# 4                  0                       0                               0
#
#    reserved_room_type  assigned_room_type  booking_changes  deposit_type  \
# 0                   2                   2                3             0
# 1                   2                   2                4             0
# 2                   0                   2                0             0
# 3                   0                   0                0             0
# 4                   0                   0                0             0
#
#    days_in_waiting_list  customer_type   adr  required_car_parking_spaces  \
# 0                     0              2   0.0                            0
# 1                     0              2   0.0                            0
# 2                     0              2  75.0                            0
# 3                     0              2  75.0                            0
# 4                     0              2  98.0                            0
#
#    total_of_special_requests  year  month  day
# 0                          0     1      7    1
# 1                          0     1      7    1
# 2                          0     1      7    2
# 3                          0     1      7    2
# 4                          1     1      7    3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85427 entries, 0 to 119385
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           85427 non-null  int64
#  1   is_canceled                     85427 non-null  int64
#  2   lead_time                       85427 non-null  int64
#  3   arrival_date_week_number        85427 non-null  int64
#  4   arrival_date_day_of_month       85427 non-null  int64
#  5   stays_in_weekend_nights         85427 non-null  int64
#  6   stays_in_week_nights            85427 non-null  int64
#  7   adults                          85427 non-null  int64
#  8   children                        85427 non-null  int64
#  9   babies                          85427 non-null  int64
#  10  meal                            85427 non-null  int64
#  11  market_segment                  85427 non-null  int64
#  12  distribution_channel            85427 non-null  int64
#  13  is_repeated_guest               85427 non-null  int64
#  14  previous_cancellations          85427 non-null  int64
#  15  previous_bookings_not_canceled  85427 non-null  int64
#  16  reserved_room_type              85427 non-null  int64
#  17  assigned_room_type              85427 non-null  int64
#  18  booking_changes                 85427 non-null  int64
#  19  deposit_type                    85427 non-null  int64
#  20  days_in_waiting_list            85427 non-null  int64
#  21  customer_type                   85427 non-null  int64
#  22  adr                             85427 non-null  float64
#  23  required_car_parking_spaces     85427 non-null  int64
#  24  total_of_special_requests       85427 non-null  int64
#  25  year                            85427 non-null  int64
#  26  month                           85427 non-null  int64
#  27  day                             85427 non-null  int64
# dtypes: float64(1), int64(27)
# memory usage: 18.9 MB

# %% [markdown]
# ## StandartScale

# %%
df.var()
# Out:
# hotel                                0.238554
# is_canceled                          0.201918
# lead_time                         7313.020113
# arrival_date_week_number           186.616969
# arrival_date_day_of_month           78.158589
# stays_in_weekend_nights              1.060883
# stays_in_week_nights                 4.197863
# adults                               0.386915
# children                             0.211678
# babies                               0.013164
# meal                                 1.171499
# market_segment                       1.804945
# distribution_channel                 0.884936
# is_repeated_guest                    0.037774
# previous_cancellations               0.139275
# previous_bookings_not_canceled       3.066050
# reserved_room_type                   3.394844
# assigned_room_type                   3.921137
# booking_changes                      0.508052
# deposit_type                         0.016151
# days_in_waiting_list                92.179692
# customer_type                        0.272797
# adr                               3045.367104
# required_car_parking_spaces          0.080688
# total_of_special_requests            0.695074
# year                                 0.461891
# month                               10.440251
# day                                 77.339793
# dtype: float64

# %%
df.head()
# Out:
#    hotel  is_canceled  lead_time  arrival_date_week_number  \
# 0      1            0        342                        27
# 1      1            0        737                        27
# 2      1            0          7                        27
# 3      1            0         13                        27
# 4      1            0         14                        27
#
#    arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 0                          1                        0                     0
# 1                          1                        0                     0
# 2                          1                        0                     1
# 3                          1                        0                     1
# 4                          1                        0                     2
#
#    adults  children  babies  meal  market_segment  distribution_channel  \
# 0       2         0       0     0               3                     1
# 1       2         0       0     0               3                     1
# 2       1         0       0     0               3                     1
# 3       1         0       0     0               2                     0
# 4       2         0       0     0               6                     3
#
#    is_repeated_guest  previous_cancellations  previous_bookings_not_canceled  \
# 0                  0                       0                               0
# 1                  0                       0                               0
# 2                  0                       0                               0
# 3                  0                       0                               0
# 4                  0                       0                               0
#
#    reserved_room_type  assigned_room_type  booking_changes  deposit_type  \
# 0                   2                   2                3             0
# 1                   2                   2                4             0
# 2                   0                   2                0             0
# 3                   0                   0                0             0
# 4                   0                   0                0             0
#
#    days_in_waiting_list  customer_type   adr  required_car_parking_spaces  \
# 0                     0              2   0.0                            0
# 1                     0              2   0.0                            0
# 2                     0              2  75.0                            0
# 3                     0              2  75.0                            0
# 4                     0              2  98.0                            0
#
#    total_of_special_requests  year  month  day
# 0                          0     1      7    1
# 1                          0     1      7    1
# 2                          0     1      7    2
# 3                          0     1      7    2
# 4                          1     1      7    3

# %%
cat_cols.append('is_canceled')

# %%
#cat_cols.append( 'is_repeated_guest')

# %%
cat_cols
# Out:
# ['hotel',
#  'meal',
#  'market_segment',
#  'distribution_channel',
#  'reserved_room_type',
#  'assigned_room_type',
#  'deposit_type',
#  'customer_type',
#  'year',
#  'is_canceled']

# %%
cat_var = df[cat_cols]
cat_var.head()
# Out:
#    hotel  meal  market_segment  distribution_channel  reserved_room_type  \
# 0      1     0               3                     1                   2
# 1      1     0               3                     1                   2
# 2      1     0               3                     1                   0
# 3      1     0               2                     0                   0
# 4      1     0               6                     3                   0
#
#    assigned_room_type  deposit_type  customer_type  year  is_canceled
# 0                   2             0              2     1            0
# 1                   2             0              2     1            0
# 2                   2             0              2     1            0
# 3                   0             0              2     1            0
# 4                   0             0              2     1            0

# %%
num_cols = df.drop(columns=cat_cols)
num_cols.head()
# Out:
#    lead_time  arrival_date_week_number  arrival_date_day_of_month  \
# 0        342                        27                          1
# 1        737                        27                          1
# 2          7                        27                          1
# 3         13                        27                          1
# 4         14                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2         0       0
# 1                        0                     0       2         0       0
# 2                        0                     1       1         0       0
# 3                        0                     1       1         0       0
# 4                        0                     2       2         0       0
#
#    is_repeated_guest  previous_cancellations  previous_bookings_not_canceled  \
# 0                  0                       0                               0
# 1                  0                       0                               0
# 2                  0                       0                               0
# 3                  0                       0                               0
# 4                  0                       0                               0
#
#    booking_changes  days_in_waiting_list   adr  required_car_parking_spaces  \
# 0                3                     0   0.0                            0
# 1                4                     0   0.0                            0
# 2                0                     0  75.0                            0
# 3                0                     0  75.0                            0
# 4                0                     0  98.0                            0
#
#    total_of_special_requests  month  day
# 0                          0      7    1
# 1                          0      7    1
# 2                          0      7    2
# 3                          0      7    2
# 4                          1      7    3

# %%
#num_cols['arrival_date_day_of_month'] =

# %%
from sklearn.preprocessing import StandardScaler
sca = StandardScaler()
X_temp= sca.fit_transform(num_cols)
X_temp = pd.DataFrame(X_temp, columns= num_cols.columns)

# %%
X_temp.head()
# Out:
#    lead_time  arrival_date_week_number  arrival_date_day_of_month  \
# 0   3.069363                  0.013153                   -1.67532
# 1   7.688398                  0.013153                   -1.67532
# 2  -0.848046                  0.013153                   -1.67532
# 3  -0.777884                  0.013153                   -1.67532
# 4  -0.766190                  0.013153                   -1.67532
#
#    stays_in_weekend_nights  stays_in_week_nights    adults  children  \
# 0                -0.979707             -1.285557  0.183863  -0.30753
# 1                -0.979707             -1.285557  0.183863  -0.30753
# 2                -0.979707             -0.797480 -1.423798  -0.30753
# 3                -0.979707             -0.797480 -1.423798  -0.30753
# 4                -0.979707             -0.309402  0.183863  -0.30753
#
#      babies  is_repeated_guest  previous_cancellations  \
# 0 -0.096209           -0.20231               -0.083185
# 1 -0.096209           -0.20231               -0.083185
# 2 -0.096209           -0.20231               -0.083185
# 3 -0.096209           -0.20231               -0.083185
# 4 -0.096209           -0.20231               -0.083185
#
#    previous_bookings_not_canceled  booking_changes  days_in_waiting_list  \
# 0                       -0.107318         3.833545             -0.071077
# 1                       -0.107318         5.236515             -0.071077
# 2                       -0.107318        -0.375365             -0.071077
# 3                       -0.107318        -0.375365             -0.071077
# 4                       -0.107318        -0.375365             -0.071077
#
#         adr  required_car_parking_spaces  total_of_special_requests     month  \
# 0 -1.935646                    -0.302358                  -0.844568  0.228972
# 1 -1.935646                    -0.302358                  -0.844568  0.228972
# 2 -0.576569                    -0.302358                  -0.844568  0.228972
# 3 -0.576569                    -0.302358                  -0.844568  0.228972
# 4 -0.159785                    -0.302358                   0.354895  0.228972
#
#         day
# 0 -1.677185
# 1 -1.677185
# 2 -1.563474
# 3 -1.563474
# 4 -1.449764

# %%
frames = [cat_var, X_temp]

# %%
df = pd.concat([cat_var.reset_index(drop=True), X_temp.reset_index(drop=True)], axis = 1)

# %%
df.head()
# Out:
#    hotel  meal  market_segment  distribution_channel  reserved_room_type  \
# 0      1     0               3                     1                   2
# 1      1     0               3                     1                   2
# 2      1     0               3                     1                   0
# 3      1     0               2                     0                   0
# 4      1     0               6                     3                   0
#
#    assigned_room_type  deposit_type  customer_type  year  is_canceled  \
# 0                   2             0              2     1            0
# 1                   2             0              2     1            0
# 2                   2             0              2     1            0
# 3                   0             0              2     1            0
# 4                   0             0              2     1            0
#
#    lead_time  arrival_date_week_number  arrival_date_day_of_month  \
# 0   3.069363                  0.013153                   -1.67532
# 1   7.688398                  0.013153                   -1.67532
# 2  -0.848046                  0.013153                   -1.67532
# 3  -0.777884                  0.013153                   -1.67532
# 4  -0.766190                  0.013153                   -1.67532
#
#    stays_in_weekend_nights  stays_in_week_nights    adults  children  \
# 0                -0.979707             -1.285557  0.183863  -0.30753
# 1                -0.979707             -1.285557  0.183863  -0.30753
# 2                -0.979707             -0.797480 -1.423798  -0.30753
# 3                -0.979707             -0.797480 -1.423798  -0.30753
# 4                -0.979707             -0.309402  0.183863  -0.30753
#
#      babies  is_repeated_guest  previous_cancellations  \
# 0 -0.096209           -0.20231               -0.083185
# 1 -0.096209           -0.20231               -0.083185
# 2 -0.096209           -0.20231               -0.083185
# 3 -0.096209           -0.20231               -0.083185
# 4 -0.096209           -0.20231               -0.083185
#
#    previous_bookings_not_canceled  booking_changes  days_in_waiting_list  \
# 0                       -0.107318         3.833545             -0.071077
# 1                       -0.107318         5.236515             -0.071077
# 2                       -0.107318        -0.375365             -0.071077
# 3                       -0.107318        -0.375365             -0.071077
# 4                       -0.107318        -0.375365             -0.071077
#
#         adr  required_car_parking_spaces  total_of_special_requests     month  \
# 0 -1.935646                    -0.302358                  -0.844568  0.228972
# 1 -1.935646                    -0.302358                  -0.844568  0.228972
# 2 -0.576569                    -0.302358                  -0.844568  0.228972
# 3 -0.576569                    -0.302358                  -0.844568  0.228972
# 4 -0.159785                    -0.302358                   0.354895  0.228972
#
#         day
# 0 -1.677185
# 1 -1.677185
# 2 -1.563474
# 3 -1.563474
# 4 -1.449764

# %%
X = df.drop(columns = 'is_canceled')
y = df['is_canceled']

# %%
from sklearn import model_selection
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, stratify= y,test_size = 0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
from sklearn.metrics import confusion_matrix
for model in [LogisticRegression, RandomForestClassifier, XGBClassifier]:
    cls = model()
    cls.fit(X_train, y_train)
    previsao = cls.predict(X_test)

    acuracia = accuracy_score(y_test, previsao)*100
    print(f'No modelo {model} A acurácia foi: %.2f%%' % acuracia)
    cm = confusion_matrix(y_test, previsao)
    print(cm)
    clf_report = classification_report(y_test, previsao)
    print(f"Classification Report : \n{clf_report}")
# Out:
# No modelo <class 'sklearn.linear_model._logistic.LogisticRegression'> A acurácia foi: 79.55%
# [[11657   633]
#  [ 2861  1935]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.80      0.95      0.87     12290
#            1       0.75      0.40      0.53      4796
#
#     accuracy                           0.80     17086
#    macro avg       0.78      0.68      0.70     17086
# weighted avg       0.79      0.80      0.77     17086
#
# No modelo <class 'sklearn.ensemble._forest.RandomForestClassifier'> A acurácia foi: 92.95%
# [[12168   122]
#  [ 1083  3713]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95     12290
#            1       0.97      0.77      0.86      4796
#
#     accuracy                           0.93     17086
#    macro avg       0.94      0.88      0.91     17086
# weighted avg       0.93      0.93      0.93     17086
#
# No modelo <class 'xgboost.sklearn.XGBClassifier'> A acurácia foi: 99.73%
# [[12283     7]
#  [   39  4757]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     12290
#            1       1.00      0.99      1.00      4796
#
#     accuracy                           1.00     17086
#    macro avg       1.00      1.00      1.00     17086
# weighted avg       1.00      1.00      1.00     17086
